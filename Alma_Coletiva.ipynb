# %% [markdown]
# <a href="https://colab.research.google.com/github/brunotonet/imersao_Inteligencia_alura/blob/main/Alma_Coletiva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Visão Geral:**
#
# O projeto Alma Coletiva - SOS Rio Grande do Sul é uma resposta direta às necessidades urgentes das comunidades atingidas por enchentes. Nosso foco é garantir que informações vitais sobre recursos essenciais estejam ao alcance de todos, quando mais precisam.
#
# **Objetivo Principal:**
#
# Desenvolver um chatbot acessível, servindo como assistente virtual para fornecer informações precisas e atualizadas sobre a disponibilidade de itens fundamentais como alimentos, água potável, medicamentos, roupas, além de abrigos e outros serviços.
#
# **Estratégias de Ação:**
#
# - Centralização de Informações: Uma única plataforma para acessar dados confiáveis sobre recursos e serviços de ajuda.
# - Atualizações Dinâmicas: Informações em tempo real para atender às necessidades emergentes das comunidades.
# - Integração Comunitária: Conexão efetiva entre afetados, distribuidores, varejistas, pontos de auxílio e autoridades.
# - Otimização de Recursos: Melhoria na distribuição de recursos, assegurando apoio rápido e organizado.
#
# **Impacto Esperado:**
#
# A implementação do **Alma Coletiva - SOS Rio Grande do Sul** pretende fortalecer a capacidade de recuperação das comunidades, proporcionando uma resposta coordenada e eficiente em tempos de crise.
#
# **Iniciado:**
# Objetivo é centrar as informaçõesque vai servir de base de fonte de dados, com informações sobre entidades que oferecem serviços e recursos. Esse documento deve possuir os seguinte colunas e dados:
#
# ## Descrição dos Campos do CSV
#
# 1. **Categoria**: Tipo de serviço ou recurso oferecido pela entidade (ex: Supermercado, Farmácia, Centro de Ajuda Humanitária) ** Ver mais sobre Descrição das cotegorias.
#
# 2. **NomeEntidade**: Nome oficial da entidade, organização ou estabelecimento.
#
# 3. **Endereço**: Endereço completo da entidade, incluindo rua, número, complemento, bairro e municipio. Seguindo o formato "Rua, Número - Bairro, Município". Exemplo: "Av. Assis Brasil, 1234 - Passo D'Areia, Porto Alegre". Esta formatação ajuda na identificação precisa da localização.
#
# 4. **Localização Latitude**: Coordenada geográfica da latitude da entidade, facilitando a localização por GPS.
#
# 5. **Localização Longitude**: Coordenada geográfica da longitude da entidade, complementando a informação para localização precisa.
#
# 6. **Contato**: Números de telefone, e-mail ou outros meios de contato com a entidade.
#
# 7. **HorarioFuncionamento**: Dias e horários em que a entidade está aberta e disponível para o público.
#
# 8. **ItensDisponiveis**: Lista de itens que podem ser encontrados ou adquiridos na entidade (ex: alimentos, medicamentos, roupas).
#
# 9. **ServicosOferecidos**: Descrição dos serviços que a entidade oferece (ex: consultas médicas, distribuição de alimentos, abrigo temporário).
#
# 10. **DataAtualizacao**: Data da última atualização das informações fornecidas, indicando a relevância e precisão dos dado.
#
# ## Categorias de Recursos e Serviços para Auxílio em Enchentes
#
# 1. **Supermercados**: Alimentos e itens de primeira necessidade.
# 2. **Farmácias**: Medicamentos e produtos de higiene.
# 3. **Centros de Ajuda Humanitária**: Assistência direta, como alimentos e roupas.
# 4. **ONGs**: Serviços variados, incluindo assistência médica e psicológica.
# 5. **Postos de Saúde**: Cuidados médicos básicos e vacinação.
# 6. **Defesa Civil**: Coordenação de resposta a desastres.
# 7. **Igrejas e Centros Religiosos**: Abrigo e apoio espiritual.
# 8. **Escolas**: Abrigo temporário e distribuição de suprimentos.
# 9. **Centros Comunitários**: Diversos tipos de assistência e coleta de doações.
# 10. **Empresas de Utilidade Pública**: Informações sobre serviços essenciais como água e energia.
# 11. **Serviços de Limpeza e Sanitização**: Limpeza de áreas afetadas.
# 12. **Assistência Psicológica**: Apoio para saúde mental.
# 13. **Transporte**: Serviços para evacuação e deslocamento.
# 14. **Voluntariado**: Coordenação de esforços de voluntários.
# 15. **Reparos e Construção**: Auxílio na recuperação de infraestruturas.

# %% [markdown]
# Esse exemplo foi gerado via Gemili pelo seguinte comando:
#
# "Para facilitar a localização e o acesso aos serviços e itens essenciais, preciso em forma de uma tabela contendo as seguintes colunas: Categoria, Nome da Entidade, Endereço, Latitude, Longitude, Contato, Horário de Funcionamento, Itens Disponíveis, Serviços Oferecidos e Data de Atualização.
#
# O endereço de cada entidade será detalhado, seguindo o formato "Rua, Número - Bairro, Município", para permitir uma identificação precisa. As categorias incluem, mas não se limitam a, Supermercados, Farmácias, Centros de Ajuda, Hospitais, entre outros. Os serviços oferecidos abrangem desde doações de alimentos e produtos de higiene até atendimento médico e vacinação.
#
# As informações serão coletadas das cidades de Porto Alegre, Caxias do Sul, Lajeado, Estrela e Santa Maria, garantindo uma cobertura ampla e diversificada de serviços."
#
# ![image.png](data:image/png;base64,...)
#
# Os dados foram exportados com sucesso e estão armazenados de forma segura no Google Drive. É crucial destacar que esses dados são representativos e servem como exemplos ilustrativos. Eles não devem ser interpretados como informações definitivas. Encorajamos a realização de pesquisas independentes e a consulta de fontes adicionais para a verificação dos dados. O propósito é demonstrar um modelo que possa ser adaptado e utilizado conforme necessário.
# https://gemini.google.com/app
#
# ![image.png](data:image/png;base64,...)
#
# Exemplo de algumas buscas de dados e centralizados em local publico e dispónivel.
# https://docs.google.com/spreadsheets/d/e/2PACX-1vQdSmnsM6koFN3XD1nt6dNgtNuUadMwSJClNCcvJ6U5shsaWYSifaYas8KOHqoLg0y-M3kkVhaMQwwx/pub?output=csv

# %%
# Importando Bibliotecar para obter o dados.
import requests
import io
import csv

# URL do arquivo CSV (substitua pelo URL real)
spreadsheet_url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vQdSmnsM6koFN3XD1nt6dNgtNuUadMwSJClNCcvJ6U5shsaWYSifaYas8KOHqoLg0y-M3kkVhaMQwwx/pub?output=csv'

# Faz o download do arquivo CSV
response = requests.get(spreadsheet_url)

# Verifica se o download foi bem-sucedido
response.raise_for_status()

# Lê o conteúdo do CSV usando o módulo csv
csv_data = csv.reader(io.StringIO(response.text))

# Imprime os dados
for row in csv_data:
  print(row)
# Out:
# ['Categoria', 'NomeEntidade', 'EndereÃ§o', 'LocalizaÃ§Ã£o Latitude', 'LocalizaÃ§Ã£o Longitude', 'Contato', 'HorarioFuncionamento', 'ItensDisponiveis', 'ServicosOferecidos', 'DataAtualizacao']
# ['Supermercado', "Carrefour Passo D'Areia", "Av. Assis Brasil, 1234 - Passo D'Areia, Porto Alegre", '-30.054.589', '-51.153.473', '(51) 3012-3456', 'Segunda a sÃ¡bado das 8h Ã\xa0s 22h, domingo das 9h Ã\xa0s 20h', 'Alimentos nÃ£o perecÃ\xadveis, Ã¡gua potÃ¡vel', 'DoaÃ§Ãµes de alimentos nÃ£o perecÃ\xadveis e Ã¡gua potÃ¡vel.', '11/05/2024']
# ['Hipermercado', 'Big SÃ£o CristÃ³vÃ£o', 'Av. SertÃ³rio, 1234 - SÃ£o CristÃ³vÃ£o, Porto Alegre', '-30.045.678', '-51.168.901', '(51) 3022-7890', 'Segunda a sÃ¡bado das 8h Ã\xa0s 22h, domingo das 9h Ã\xa0s 20h', 'Alimentos nÃ£o perecÃ\xadveis, Ã¡gua potÃ¡vel', 'DaÃ§Ãµes de alimentos nÃ£o perecÃ\xadveis e Ã¡gua potÃ¡vel.', '11/05/2024']
# ...

# %% [markdown]
# Ajustando os Caracteres Especiais

# %%
### PROBLEMAS DE CARACTERES
# Decodifica o texto da resposta usando a codificação 'latin-1' (ajuste se necessário)
decoded_text = response.text.encode('latin-1').decode('utf-8', errors='replace')

# Cria o objeto StringIO com o texto decodificado
csv_data = list(csv.reader(io.StringIO(decoded_text)))

# Imprime os dados
for row in csv_data:
  print(row)
# Out:
# ['Categoria', 'NomeEntidade', 'Endereço', 'Localização Latitude', 'Localização Longitude', 'Contato', 'HorarioFuncionamento', 'ItensDisponiveis', 'ServicosOferecidos', 'DataAtualizacao']
# ['Supermercado', "Carrefour Passo D'Areia", "Av. Assis Brasil, 1234 - Passo D'Areia, Porto Alegre", '-30.054.589', '-51.153.473', '(51) 3012-3456', 'Segunda a sábado das 8h às 22h, domingo das 9h às 20h', 'Alimentos não perecíveis, água potável', 'Doações de alimentos não perecíveis e água potável.', '11/05/2024']
# ['Hipermercado', 'Big São Cristóvão', 'Av. Sertório, 1234 - São Cristóvão, Porto Alegre', '-30.045.678', '-51.168.901', '(51) 3022-7890', 'Segunda a sábado das 8h às 22h, domingo das 9h às 20h', 'Alimentos não perecíveis, água potável', 'Dações de alimentos não perecíveis e água potável.', '11/05/2024']
# ...

# %% [markdown]
# Para converter o texto em um formato JSON que possa ser usado com DataForms, como mencionado na aula 5, você precisará estruturar os dados em pares de chave-valor.

# %%
# Bibliotecas trabalhar com JSON.
import json

# Extrai os cabeçalhos da primeira linha
headers = csv_data[0]

# Cria uma lista de dicionários
json_data = []
for row in csv_data[1:]:  # Começa da segunda linha
  json_data.append(dict(zip(headers, row)))

# Converte para JSON
json_output = json.dumps(json_data, indent=4)

# Imprime o JSON
print(json_output)
# Out:
# [
#     {
#         "Categoria": "Supermercado",
#         "NomeEntidade": "Carrefour Passo D'Areia",
#         "Endere\u00e7o": "Av. Assis Brasil, 1234 - Passo D'Areia, Porto Alegre",
#         "Localiza\u00e7\u00e3o Latitude": "-30.054.589",
#         "Localiza\u00e7\u00e3o Longitude": "-51.153.473",
#         "Contato": "(51) 3012-3456",
#         "HorarioFuncionamento": "Segunda a s\u00e1bado das 8h \u00e0s 22h, domingo das 9h \u00e0s 20h",
#         "ItensDisponiveis": "Alimentos n\u00e3o perec\u00edveis, \u00e1gua pot\u00e1vel",
#         "ServicosOferecidos": "Doa\u00e7\u00f5es de alimentos n\u00e3o perec\u00edveis e \u00e1gua pot\u00e1vel.",
#         "DataAtualizacao": "11/05/2024"
#     },
#     {
#         "Categoria": "Hipermercado",
#         "NomeEntidade": "Big S\u00e3o Crist\u00f3v\u00e3o",
#         "Endere\u00e7o": "Av. Sert\u00f3rio, 1234 - S\u00e3o Crist\u00f3v\u00e3o, Porto Alegre",
#         "Localiza\u00e7\u00e3o Latitude": "-30.045.678",
# ...

# %% [markdown]
# Depois do JSON, vamos crir o nosso DataFrame

# %%
# Bibliotecas trabalhar com dados.
import pandas               as pd
import numpy                as np

#usado para converter uma string JSON (json_output) de volta para um objeto Python (lista ou dicionário).
json_data = json.loads(json_output)

# **Cria o DataFrame diretamente a partir de json_data (lista de dicionários)**
df = pd.DataFrame(json_data)

# Define os nomes das colunas
df.columns = ["Categoria", "NomeEntidade", "Endereco", "Latitude",
              "Longitude", "Contato", "HorarioFuncionamento",
              "ItensDisponiveis", "ServicosOferecidos", "DataAtualizacao"]

# Agora você pode trabalhar com o DataFrame df
df
# Out:
#                       Categoria  \
# 0                  Supermercado
# 1                  Hipermercado
# 2                Loja de Roupas
# 3      Loja de Eletrodomésticos
# 4                        Escola
# 5                  Universidade
# 6          Prefeitura Municipal
# 7   Centro de Ajuda Humanitária
# 8                Loja de Roupas
# 9                  Supermercado
# 10               Posto de Saúde
# 11                          ONG
# 12         Prefeitura Municipal
# 13                Supermercados
# 14                Supermercados
# 15                Supermercados
# 16                    Farmácias
# 17                    Farmácias
# 18  Centro de Ajuda Humanitária
# 19  Centro de Ajuda Humanitária
# 20  Centro de Ajuda Humanitária
# 21  Centro de Ajuda Humanitária
# 22  Centro de Ajuda Humanitária
# 23              Igreja Católica
# 24            Igreja Evangélica
# 25              Centro Espírita
# 26               Templo Budista
# 27                     Mesquita
# ...

# %% [markdown]
#  Processo de instalação e atualização da última versão da API GenerativeAI, vinculada ao Google AI Studio

# %%
# !pip install -q -U google-generativeai
# !pip install -q -U google-api-python-client

# %% [markdown]
# Aqui importação e confirguração para API GenerativeAI.
# E vamos criar um Modelo controlado, utilizando neste caso conteúdo em texto que será enviado à API para gerar embeddings. Ou seja, é o dado de entrada que a API processará para criar a representação vetorial.

# %%
import google.generativeai as genai
from google.colab    import userdata

## Chave
GOOGLE_API_KEY= userdata.get('SECRET_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

## Lista os Modelos disponiveis
for m in genai.list_models():
  if 'embedContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %% [markdown]
# Vamos gerar o modelo controlado para realizar as pesquisas.

# %%
model = "models/embedding-001"

# exceeds the limit: 10000 bytes. Tive que mudar os argumentos por causa do limite.
#def concatenate_columns(row):
#  text = ""
#  for column in df.columns:
#    text += str(row[column]) + " "
#  return text.strip()

# Deixei as colunas que acredito ser mais importantes.
def concatenate_columns(row):
  text = str(row["ItensDisponiveis"]) + str(row["ServicosOferecidos"]) + str(row["Endereco"])
  return text.strip()

def embed_fn(title, text):
  return genai.embed_content(model=model,
                                 content=text,
                                 title=title,
                                 task_type="RETRIEVAL_DOCUMENT")["embedding"]
df["Embeddings"] = df.apply(lambda row: embed_fn(row["Categoria"], concatenate_columns(row)), axis=1)
df
# Out:
#                       Categoria  \
# 0                  Supermercado
# 1                  Hipermercado
# 2                Loja de Roupas
# 3      Loja de Eletrodomésticos
# 4                        Escola
# 5                  Universidade
# 6          Prefeitura Municipal
# 7   Centro de Ajuda Humanitária
# 8                Loja de Roupas
# 9                  Supermercado
# 10               Posto de Saúde
# 11                          ONG
# 12         Prefeitura Municipal
# 13                Supermercados
# 14                Supermercados
# 15                Supermercados
# 16                    Farmácias
# 17                    Farmácias
# 18  Centro de Ajuda Humanitária
# 19  Centro de Ajuda Humanitária
# 20  Centro de Ajuda Humanitária
# 21  Centro de Ajuda Humanitária
# 22  Centro de Ajuda Humanitária
# 23              Igreja Católica
# 24            Igreja Evangélica
# 25              Centro Espírita
# 26               Templo Budista
# 27                     Mesquita
# ...

# %% [markdown]
# Testando o MODELO

# %%
def gerar_e_buscar_consulta(consulta, base, model):
  embedding_da_consulta = genai.embed_content(model=model,
                                 content=consulta,
                                 task_type="RETRIEVAL_QUERY")["embedding"]

  produtos_escalares = np.dot(np.stack(df["Embeddings"]), embedding_da_consulta)

  indice = np.argmax(produtos_escalares)
  return df.iloc[indice]

consulta = "Preciso de agua? Santa maria"

trecho = gerar_e_buscar_consulta(consulta, df, model)

print(trecho)
# Out:
# Categoria                                                    Supermercado
# NomeEntidade                             Caritas Diocesana de Santa Maria
# Endereco                        Rua Riachuelo, 2000 - Centro, Santa Maria
# Latitude                                                      -29.313.056
# Longitude                                                     -51.179.722
# Contato                                                    (55) 3233-4444
# HorarioFuncionamento                           Segunda a sexta: 8h às 17h
# ItensDisponiveis                             Cestas básicas com alimentos
# ServicosOferecidos                         Distribuição de cestas básicas
# DataAtualizacao                                                11/05/2024
# Embeddings              [0.029513884, -0.040558714, -0.05843015, -0.01...
# Name: 33, dtype: object

# %% [markdown]
# Deixando mais amigavel e utilizando o Modelo gemini-1.0-pro.

# %%
generation_config = {
  "temperature": 0,
  "candidate_count": 1
}
prompt = f"Reescreva esse texto de uma forma mais amigavel, adicionar o mapa do local com os dados latitude e Longitude: {trecho}"

model_2 = genai.GenerativeModel("gemini-1.0-pro",
                                generation_config=generation_config)
resposta = model_2.generate_content(prompt)
print(response.text)
# Out:
# Categoria,NomeEntidade,EndereÃ§o,LocalizaÃ§Ã£o Latitude,LocalizaÃ§Ã£o Longitude,Contato,HorarioFuncionamento,ItensDisponiveis,ServicosOferecidos,DataAtualizacao
# Supermercado,Carrefour Passo D'Areia,"Av. Assis Brasil, 1234 - Passo D'Areia, Porto Alegre",-30.054.589,-51.153.473,(51) 3012-3456,"Segunda a sÃ¡bado das 8h Ã s 22h, domingo das 9h Ã s 20h","Alimentos nÃ£o perecÃ­veis, Ã¡gua potÃ¡vel",DoaÃ§Ãµes de alimentos nÃ£o perecÃ­veis e Ã¡gua potÃ¡vel.,11/05/2024
# Hipermercado,Big SÃ£o CristÃ³vÃ£o,"Av. SertÃ³rio, 1234 - SÃ£o CristÃ³vÃ£o, Porto Alegre",-30.045.678,-51.168.901,(51) 3022-7890,"Segunda a sÃ¡bado das 8h Ã s 22h, domingo das 9h Ã s 20h","Alimentos nÃ£o perecÃ­veis, Ã¡gua potÃ¡vel",DaÃ§Ãµes de alimentos nÃ£o perecÃ­veis e Ã¡gua potÃ¡vel.,11/05/2024
# ...

# %% [markdown]
# Arrumando a visualização

# %%
import textwrap
from IPython.display import Markdown

## Criando função para imprimir
def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
to_markdown(resposta.text)
# Out:
# > **Caritas Diocesana de Santa Maria: Um Supermercado Solidário**
# >
# > Olá, pessoal!
# >
# > Estamos aqui para apresentar a vocês um lugar especial que oferece ajuda para quem mais precisa: a Caritas Diocesana de Santa Maria.
# >
# > **Onde fica?**
# >
# > Você pode encontrá-la na Rua Riachuelo, 2000, no Centro de Santa Maria.
# >
# > **Como chegar?**
# >
# > Para facilitar, aqui está um mapa com a localização exata:
# >
# > [Mapa com latitude -29.313.056 e longitude -51.179.722]
# >
# > **O que eles oferecem?**
# >
# > A Caritas Diocesana distribui cestas básicas com alimentos para famílias carentes.
# >
# > **Quando posso ir?**
# >
# > Eles atendem de segunda a sexta, das 8h às 17h.
# >
# > **Como entrar em contato?**
# >
# > Se você tiver alguma dúvida, pode ligar para (55) 3233-4444.
# >
# > **Informações importantes:**
# >
# > * Data de atualização: 11/05/2024
# > * A Caritas Diocesana é uma organização sem fins lucrativos que depende de doações para continuar seu trabalho.
# ...

# %% [markdown]
# Mudando Para o modelo gemini-1.5-pro-latest

# %%
# Nome do modelo
model_name = "gemini-1.5-pro-latest"

# Define as configurações de segurança
from google.generativeai.types import HarmCategory, HarmBlockThreshold

safety_settings={
        HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
        HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
        HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE
}

generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 0,
  ##"response_mime_type": "application/json", ## Retorno em JSON
}

# Cria um modelo generativo com os atributos especificados
system_instruction = "Gere respostas positivas e seguras."

modelo2 = genai.GenerativeModel(model_name=model_name,
                              generation_config=generation_config,
                              system_instruction=system_instruction,
                              safety_settings=safety_settings)

prompt = f"Reescreva esse texto de uma forma mais amigavel, adicionar o mapa do local com os dados latitude e Longitude: {trecho}"

resposta = model_2.generate_content(prompt)
to_markdown(resposta.text)
# Out:
# > **Caritas Diocesana de Santa Maria: Um Supermercado Solidário**
# >
# > Olá, pessoal!
# >
# > Estamos aqui para apresentar a vocês um lugar especial que oferece ajuda para quem mais precisa: a Caritas Diocesana de Santa Maria.
# >
# > **Onde fica?**
# >
# > Você pode encontrá-la na Rua Riachuelo, 2000, no Centro de Santa Maria.
# >
# > **Como chegar?**
# >
# > Para facilitar, aqui está um mapa com a localização exata:
# >
# > [Mapa com latitude -29.313.056 e longitude -51.179.722]
# >
# > **O que eles oferecem?**
# >
# > A Caritas Diocesana distribui cestas básicas com alimentos para famílias carentes.
# >
# > **Quando posso ir?**
# >
# > Eles atendem de segunda a sexta, das 8h às 17h.
# >
# > **Como entrar em contato?**
# >
# > Se você tiver alguma dúvida, pode ligar para (55) 3233-4444.
# >
# > **Informações importantes:**
# >
# > * Data de atualização: 11/05/2024
# > * A Caritas Diocesana é uma organização sem fins lucrativos que depende de doações para continuar seu trabalho.
# ...

# %% [markdown]
# Projeto final - Testando o CHAT
# Para encerrar a sessão de chat, digite"FIM"..
# Certifique-se de executar todos os procedimentos anteriores para que o sistema reconheça o modelo configurado nesta etapa.

# %%
# Inicia uma nova sessão de chat: Ativa o modelo modelo2 para receber e responder mensagens em tempo real.
chat = modelo2.start_chat(history=[])

consulta = input('Informa a cidade e que precisa? \n\n')

while consulta != "fim":
  ## Dentro do Modelo criado.
  trecho = gerar_e_buscar_consulta(consulta, df, model)

  # print(trecho) # Testar informação

  ## Deixando mais Amigavel
  regra_comando = f"Reescreva esse texto de uma forma mais amigavel, adicionar o mapa do local com os dados latitude e Longitude: {trecho}"
  resposta = model_2.generate_content(regra_comando)
  print('------------------------------------------')
  print(resposta.text)
  print('------------------------------------------')
  consulta = input('Informa a cidade e que precisa? \n\n')
# Out:
# Informa a cidade e que precisa?
#
# Agua Caxias do sul
# ------------------------------------------
# **Prefeitura Municipal de Caxias do Sul**
#
# **Endereço:** Av. Júlio de Castilhos, 1234 - Centro, Caxias do Sul
#
# **Localização:**
#
# [Mapa do local](https://www.google.com/maps/place/Prefeitura+Municipal+de+Caxias+do+Sul/@-29.178901,-51.181234,17z/data=!3m1!4b1!4m5!3m4!1s0x9519784488444445:0x4444444444444444!8m2!3d-29.178901!4d-51.181234)
#
# **Coordenadas:**
#
# * Latitude: -29.178.901
# * Longitude: -51.181.234
#
# **Contato:**
#
# * Telefone: (54) 3322-3456
#
# **Horário de Funcionamento:**
#
# * Segunda a sexta, das 8h às 17h
#
# **Serviços Oferecidos:**
#
# * Distribuição de cestas básicas
# * Kits de higiene pessoal
# * Materiais de limpeza
# * Atendimento social
#
# **Itens Disponíveis:**
#
# * Cestas básicas
# * Kits de higiene pessoal
# * Materiais de limpeza
#
# **Data de Atualização:**
#
# * 11/05/2024
# ------------------------------------------
# ...
